# %%
import pandas as pd
import numpy as np
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, Scaffolds #ChemicalFeatures
from rdkit.Chem.Descriptors import ExactMolWt
from rdkit.Chem.Scaffolds import MurckoScaffold
import mordred
from mordred import Calculator, descriptors

# %%
df = pd.read_csv (r'C:\documenten hier\ccr2_data.csv')
df["mol"] = df.apply(lambda row: Chem.MolFromSmiles(row['SMILES']), axis=1)
df["mol_H"] = df.apply(lambda row: Chem.AddHs(row['mol']), axis=1)
df.head()
# Out:
#                    Activity_ID Quality    source            CID  \
# 0  AAMCCXZHVCUGJS_on_P41597_WT    High  ChEMBL30   CHEMBL231340
# 1  AANWVQVQZDEWDD_on_P41597_WT     Low  ChEMBL30  CHEMBL1688881
# 2  AAZMPANXGYITPF_on_P41597_WT    High  ChEMBL30  CHEMBL1290522
# 3  ABHVKYFWPPHTHF_on_P41597_WT    High  ChEMBL30  CHEMBL3115111
# 4  ABOSMIZKCHEJEN_on_P41597_WT    High  ChEMBL30  CHEMBL1092748
#
#                                               SMILES    connectivity  \
# 0  CC1CN(CCC(C(=O)NCc2cc(C(F)(F)F)cc(C(F)(F)F)c2)...  AAMCCXZHVCUGJS
# 1     O=C(NC(=O)c1cc2c(cc1)OCO2)Nc1cc(-c2ccccc2)ccc1  AANWVQVQZDEWDD
# 2  O=C(CNC(=O)c1cccc(C(F)(F)F)c1)NC1CN(C2CCN(c3cc...  AAZMPANXGYITPF
# 3  COC1COCCC1NC1CC2CN(C(=O)OCCN3CCOCC3)CC2(C(=O)N...  ABHVKYFWPPHTHF
# 4  CC(C)N(C)C1CCC(N2CCC(NC(=O)c3cc(C(F)(F)F)cc(C(...  ABOSMIZKCHEJEN
#
#                       InChIKey  \
# 0  AAMCCXZHVCUGJS-UHFFFAOYSA-N
# 1  AANWVQVQZDEWDD-UHFFFAOYSA-N
# 2  AAZMPANXGYITPF-UHFFFAOYSA-N
# 3  ABHVKYFWPPHTHF-UHFFFAOYSA-N
# 4  ABOSMIZKCHEJEN-UHFFFAOYSA-N
#
#                                                InChI  \
# 0  InChI=1S/C37H35F6N5O2S/c1-23-21-48(15-12-35(23...
# 1  InChI=1S/C21H16N2O4/c24-20(16-9-10-18-19(12-16...
# 2  InChI=1S/C25H29F3N4O3/c26-25(27,28)18-6-4-5-17...
# 3  InChI=1S/C30H42F3N5O6/c1-41-26-18-43-8-3-25(26...
# 4  InChI=1S/C30H35F6N3O4S/c1-18(2)38(3)23-9-10-26...
#
#                                        InChI_AuxInfo  target_id  ... relation  \
# 0  "AuxInfo=1/1/N:1,50,49,36,37,51,35,48,45,6,44,...  P41597_WT  ...        =
# 1  "AuxInfo=1/1/N:22,21,23,26,20,24,25,27,11,10,1...  P41597_WT  ...        <
# 2  "AuxInfo=1/1/N:28,27,29,9,8,10,26,30,22,32,23,...  P41597_WT  ...        =
# 3  "AuxInfo=1/0/N:1,32,7,31,21,25,19,6,22,24,18,3...  P41597_WT  ...        =
# 4  "AuxInfo=1/1/N:1,3,5,41,40,42,39,43,7,8,12,11,...  P41597_WT  ...        =
#
#      pchembl_value pchembl_value_Mean pchembl_value_StdDev  pchembl_value_SEM  \
# 0            7.890               7.89                 0.00               0.00
# 1            5.000               5.00                 0.00               0.00
# 2            6.190               6.19                 0.00               0.00
# 3    7.010;  7.390               7.20                 0.19               0.19
# 4            8.460               8.46                 0.00               0.00
#
#   pchembl_value_N pchembl_value_Median pchembl_value_MAD  \
# 0             1.0                 7.89              0.00
# 1             1.0                 5.00              0.00
# 2             1.0                 6.19              0.00
# 3             2.0                 7.20              0.19
# 4             1.0                 8.46              0.00
#
#                                                  mol  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 1  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 2  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 3  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 4  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
#
#                                                mol_H
# 0  <rdkit.Chem.rdchem.Mol object at 0x00000215358...
# 1  <rdkit.Chem.rdchem.Mol object at 0x00000215358...
# 2  <rdkit.Chem.rdchem.Mol object at 0x00000215358...
# 3  <rdkit.Chem.rdchem.Mol object at 0x00000215358...
# 4  <rdkit.Chem.rdchem.Mol object at 0x00000215358...
#
# [5 rows x 33 columns]

# %%
mols = df['mol_H'].values.tolist()
print(mols)
# Out:
# [<rdkit.Chem.rdchem.Mol object at 0x00000215358AA6C0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA710>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA760>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA7B0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA800>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA850>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA8A0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA8F0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA940>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA990>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AA9E0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAA30>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAA80>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAAD0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAB20>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAB70>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AABC0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAC10>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAC60>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AACB0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAD00>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAD50>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AADA0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AADF0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAE40>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAE90>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAEE0>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAF30>, <rdkit.Chem.rdchem.Mol object at 0x00000215358AAF80>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875030>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875080>, <rdkit.Chem.rdchem.Mol object at 0x00000215348750D0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875120>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875170>, <rdkit.Chem.rdchem.Mol object at 0x00000215348751C0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875210>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875260>, <rdkit.Chem.rdchem.Mol object at 0x00000215348752B0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875300>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875350>, <rdkit.Chem.rdchem.Mol object at 0x00000215348753A0>, <rdkit.Chem.rdchem.Mol object at 0x00000215348753F0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875440>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875490>, <rdkit.Chem.rdchem.Mol object at 0x00000215348754E0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875530>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875580>, <rdkit.Chem.rdchem.Mol object at 0x00000215348755D0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875620>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875670>, <rdkit.Chem.rdchem.Mol object at 0x00000215348756C0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875710>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875760>, <rdkit.Chem.rdchem.Mol object at 0x00000215348757B0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875800>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875850>, <rdkit.Chem.rdchem.Mol object at 0x00000215348758A0>, <rdkit.Chem.rdchem.Mol object at 0x00000215348758F0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875940>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875990>, <rdkit.Chem.rdchem.Mol object at 0x00000215348759E0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875A30>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875A80>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875AD0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875B20>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875B70>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875BC0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875C10>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875C60>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875CB0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875D00>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875D50>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875DA0>, <rdkit.Chem.rdchem.Mol object at 0x0000021534875DF0>, <rd ...

# %%
df["con"] = df.apply(lambda row: AllChem.EmbedMolecule(row['mol_H']), axis=1)
df.head()
# Out:
#                    Activity_ID Quality    source            CID  \
# 0  AAMCCXZHVCUGJS_on_P41597_WT    High  ChEMBL30   CHEMBL231340
# 1  AANWVQVQZDEWDD_on_P41597_WT     Low  ChEMBL30  CHEMBL1688881
# 2  AAZMPANXGYITPF_on_P41597_WT    High  ChEMBL30  CHEMBL1290522
# 3  ABHVKYFWPPHTHF_on_P41597_WT    High  ChEMBL30  CHEMBL3115111
# 4  ABOSMIZKCHEJEN_on_P41597_WT    High  ChEMBL30  CHEMBL1092748
#
#                                               SMILES    connectivity  \
# 0  CC1CN(CCC(C(=O)NCc2cc(C(F)(F)F)cc(C(F)(F)F)c2)...  AAMCCXZHVCUGJS
# 1     O=C(NC(=O)c1cc2c(cc1)OCO2)Nc1cc(-c2ccccc2)ccc1  AANWVQVQZDEWDD
# 2  O=C(CNC(=O)c1cccc(C(F)(F)F)c1)NC1CN(C2CCN(c3cc...  AAZMPANXGYITPF
# 3  COC1COCCC1NC1CC2CN(C(=O)OCCN3CCOCC3)CC2(C(=O)N...  ABHVKYFWPPHTHF
# 4  CC(C)N(C)C1CCC(N2CCC(NC(=O)c3cc(C(F)(F)F)cc(C(...  ABOSMIZKCHEJEN
#
#                       InChIKey  \
# 0  AAMCCXZHVCUGJS-UHFFFAOYSA-N
# 1  AANWVQVQZDEWDD-UHFFFAOYSA-N
# 2  AAZMPANXGYITPF-UHFFFAOYSA-N
# 3  ABHVKYFWPPHTHF-UHFFFAOYSA-N
# 4  ABOSMIZKCHEJEN-UHFFFAOYSA-N
#
#                                                InChI  \
# 0  InChI=1S/C37H35F6N5O2S/c1-23-21-48(15-12-35(23...
# 1  InChI=1S/C21H16N2O4/c24-20(16-9-10-18-19(12-16...
# 2  InChI=1S/C25H29F3N4O3/c26-25(27,28)18-6-4-5-17...
# 3  InChI=1S/C30H42F3N5O6/c1-41-26-18-43-8-3-25(26...
# 4  InChI=1S/C30H35F6N3O4S/c1-18(2)38(3)23-9-10-26...
#
#                                        InChI_AuxInfo  target_id  ...  \
# 0  "AuxInfo=1/1/N:1,50,49,36,37,51,35,48,45,6,44,...  P41597_WT  ...
# 1  "AuxInfo=1/1/N:22,21,23,26,20,24,25,27,11,10,1...  P41597_WT  ...
# 2  "AuxInfo=1/1/N:28,27,29,9,8,10,26,30,22,32,23,...  P41597_WT  ...
# 3  "AuxInfo=1/0/N:1,32,7,31,21,25,19,6,22,24,18,3...  P41597_WT  ...
# 4  "AuxInfo=1/1/N:1,3,5,41,40,42,39,43,7,8,12,11,...  P41597_WT  ...
#
#      pchembl_value pchembl_value_Mean pchembl_value_StdDev pchembl_value_SEM  \
# 0            7.890               7.89                 0.00              0.00
# 1            5.000               5.00                 0.00              0.00
# 2            6.190               6.19                 0.00              0.00
# 3    7.010;  7.390               7.20                 0.19              0.19
# 4            8.460               8.46                 0.00              0.00
#
#    pchembl_value_N pchembl_value_Median pchembl_value_MAD  \
# 0              1.0                 7.89              0.00
# 1              1.0                 5.00              0.00
# 2              1.0                 6.19              0.00
# 3              2.0                 7.20              0.19
# 4              1.0                 8.46              0.00
#
#                                                  mol  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 1  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 2  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 3  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
# 4  <rdkit.Chem.rdchem.Mol object at 0x00000215348...
#
#                                                mol_H con
# 0  <rdkit.Chem.rdchem.Mol object at 0x00000215358...   0
# 1  <rdkit.Chem.rdchem.Mol object at 0x00000215358...   0
# 2  <rdkit.Chem.rdchem.Mol object at 0x00000215358...   0
# 3  <rdkit.Chem.rdchem.Mol object at 0x00000215358...   0
# 4  <rdkit.Chem.rdchem.Mol object at 0x00000215358...   0
#
# [5 rows x 34 columns]

# %%
# run ETKDG 5 times
cids = df.apply(lambda row: AllChem.EmbedMultipleConfs(row['mol_H'],numConfs=5), axis=1)
#print(len(cids))

rmslist = []
df.apply(lambda row: AllChem.AlignMolConformers(row['mol_H'],RMSlist=rmslist), axis=1)
print(len(rmslist))
# Out:
# 6752

# %%
from mordred import Calculator, descriptors
calc = Calculator(descriptors)
print(calc.pandas(mols))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1688/1688 [03:09<00:00,  8.91it/s]
#             ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0     40.511902  29.661289      0      1  64.530560  2.552655  5.007797
# 1     21.310663  16.232332      0      0  35.674080  2.388106  4.728757
# 2     27.451613  20.042331      0      1  44.896384  2.410688  4.765503
# 3     34.997179  24.922982      0      2  57.072553  2.597860  5.055065
# 4     34.584407  27.525691      0      1  53.732777  2.482457  4.924884
# ...         ...        ...    ...    ...        ...       ...       ...
# 1683  24.642607  20.859108      0      0  39.978521  2.432465  4.863304
# 1684  30.523828  23.966562      0      1  49.501231  2.606829  5.063503
# 1685  28.647047  19.708368      0      1  46.288686  2.453077  4.865237
# 1686  27.688420  20.588049      0      1  43.922749  2.439140  4.862159
# 1687  28.395527  20.608121      0      1  45.362290  2.433377  4.866754
#
#          SpAD_A   SpMAD_A   LogEE_A  ...      SRW10      TSRW10          MW  \
# 0     64.530560  1.265305  4.866795  ...  10.956283  105.710927  727.241566
# 1     35.674080  1.321262  4.233488  ...  10.108100   75.607656  360.111007
# 2     44.896384  1.282754  4.480658  ...  10.403869   85.330032  490.219175
# 3     57.072553  1.297103  4.728284  ...  10.851064   98.404100  625.308719
# 4     53.732777  1.221199  4.707825  ...  10.821477   95.910357  647.225247
# ...         ...       ...       ...  ...        ...         ...         ...
# 1683  39.978521  1.249329  4.381518  ...  10.362462   81.546335  497.105516
# 1684  49.501231  1.302664  4.601769  ...  10.874210   93.927529  532.266126
# 1685  46.288686  1.285797  4.529872  ...  10.610562   86.995739  503.214424
# 1686  43.922749  1.254936  4.485597  ...  10.490635   85.539745  498.210583
# 1687  45.362290  1.260064  4.510001  ...  10.529132   72.767958  512.226233
#
#            AMW  WPath  WPol  Zagreb1  Zagreb2   mZagreb1   mZagreb2
# 0     8.456297  11332    84    278.0    328.0  17.131944  10.750000
# 1     8.374675   2109    39    142.0    165.0   7.138889   5.916667
# 2     7.659675   4616    53    184.0    213.0  11.673611   7.527778
# 3     7.271032   7262    75    242.0    290.0  13.458333   9.444444
# 4     8.192725   7185    75    238.0    280.0  18.381944   9.152778
# ...        ...    ...   ...      ...      ...        ...        ...
# 1683  8.721149   2947    51    166.0    194.0  12.423611   7.013889
# 1684  7.291317   4860    67    218.0    270.0  11.958333   8.111111
# 1685  7.862725   5251    55    196.0    231.0  11.034722   7.694444
# 1686  7.908104   4400    54    188.0    218.0  12.375000   7.333333
# 1687  7.761004   4652    57    192.0    222.0  12.625000   7.583333
#
# [1688 rows x 1826 columns]

# %%
df_2 = pd.DataFrame(data = calc.pandas(mols))
df_2
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1688/1688 [03:22<00:00,  8.34it/s]
#             ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0     40.511902  29.661289      0      1  64.530560  2.552655  5.007797
# 1     21.310663  16.232332      0      0  35.674080  2.388106  4.728757
# 2     27.451613  20.042331      0      1  44.896384  2.410688  4.765503
# 3     34.997179  24.922982      0      2  57.072553  2.597860  5.055065
# 4     34.584407  27.525691      0      1  53.732777  2.482457  4.924884
# ...         ...        ...    ...    ...        ...       ...       ...
# 1683  24.642607  20.859108      0      0  39.978521  2.432465  4.863304
# 1684  30.523828  23.966562      0      1  49.501231  2.606829  5.063503
# 1685  28.647047  19.708368      0      1  46.288686  2.453077  4.865237
# 1686  27.688420  20.588049      0      1  43.922749  2.439140  4.862159
# 1687  28.395527  20.608121      0      1  45.362290  2.433377  4.866754
#
#          SpAD_A   SpMAD_A   LogEE_A  ...      SRW10      TSRW10          MW  \
# 0     64.530560  1.265305  4.866795  ...  10.956283  105.710927  727.241566
# 1     35.674080  1.321262  4.233488  ...  10.108100   75.607656  360.111007
# 2     44.896384  1.282754  4.480658  ...  10.403869   85.330032  490.219175
# 3     57.072553  1.297103  4.728284  ...  10.851064   98.404100  625.308719
# 4     53.732777  1.221199  4.707825  ...  10.821477   95.910357  647.225247
# ...         ...       ...       ...  ...        ...         ...         ...
# 1683  39.978521  1.249329  4.381518  ...  10.362462   81.546335  497.105516
# 1684  49.501231  1.302664  4.601769  ...  10.874210   93.927529  532.266126
# 1685  46.288686  1.285797  4.529872  ...  10.610562   86.995739  503.214424
# 1686  43.922749  1.254936  4.485597  ...  10.490635   85.539745  498.210583
# 1687  45.362290  1.260064  4.510001  ...  10.529132   72.767958  512.226233
#
#            AMW  WPath  WPol  Zagreb1  Zagreb2   mZagreb1   mZagreb2
# 0     8.456297  11332    84    278.0    328.0  17.131944  10.750000
# 1     8.374675   2109    39    142.0    165.0   7.138889   5.916667
# 2     7.659675   4616    53    184.0    213.0  11.673611   7.527778
# 3     7.271032   7262    75    242.0    290.0  13.458333   9.444444
# 4     8.192725   7185    75    238.0    280.0  18.381944   9.152778
# ...        ...    ...   ...      ...      ...        ...        ...
# 1683  8.721149   2947    51    166.0    194.0  12.423611   7.013889
# 1684  7.291317   4860    67    218.0    270.0  11.958333   8.111111
# 1685  7.862725   5251    55    196.0    231.0  11.034722   7.694444
# 1686  7.908104   4400    54    188.0    218.0  12.375000   7.333333
# 1687  7.761004   4652    57    192.0    222.0  12.625000   7.583333
#
# [1688 rows x 1826 columns]

# %%
# to calculate only the 2D descriptors of the dataset
calc_2 = Calculator(descriptors, ignore_3D=True)
df_2_probeer = pd.DataFrame(data = calc_2.pandas(mols))

# %%
df_2_probeer.head()

# %%
# create a new dataframe containing all unique columns of df_2 compared to df_2_probeer --> this is the list of 3D descriptors. 
df3= set(df_2).difference(df_2_probeer)
df4 = pd.DataFrame(df3)

df4[0].tolist()

# %%
# new dataframe that contains all the 3D descriptor data
df_mordred= df_2.filter(['Mor18se', 'Mor28se', 'FNSA4', 'Mor25m', 'Mor17m', 'Mor02v', 'Mor04p', 'DPSA2',
 'Mor16se', 'Mor26se', 'Mor15v', 'Mor28v', 'Mor14v', 'Mor25se',
 'Mor30m', 'Mor03p', 'PPSA4', 'Mor27m', 'Mor10se', 'PBF', 'Mor21se', 'GRAV',
 'Mor25p', 'Mor23m', 'Mor20p', 'Mor18p', 'Mor21m', 'Mor23se', 'Mor15m', 'FNSA3',
 'Mor08p', 'Mor31m', 'WNSA4', 'Mor22p', 'Mor27p', 'FPSA1', 'Mor19p', 'Mor16m',
 'Mor01p', 'WNSA3', 'Mor06', 'Mor29', 'Mor16v', 'Mor26p', 'Mor03m', 'Mor11', 'Mor25', 'Mor19m',
 'Mor17v', 'Mor14se', 'Mor31v', 'Mor19se', 'DPSA3', 'PPSA3', 'Mor09v', 'Mor06m', 'Mor17',
 'Mor11v', 'Mor15', 'Mor21v', 'Mor14p', 'WPSA4', 'Mor28', 'Mor32p',
 'Mor02p', 'FNSA5', 'Mor29v', 'Mor21', 'Mor17se', 'RPSA', 'Mor24v', 'Mor26v',
 'Mor30v', 'RPCS', 'Mor03', 'Mor02m', 'Mor19', 'PNSA4', 'Mor13v', 'Mor07p',
 'Mor08', 'Mor15se', 'Mor21p', 'GeomShapeIndex', 'TPSA', 'Mor23v', 'Mor04se', 'Mor31',
 'Mor02', 'Mor24p', 'Mor12m', 'Mor10', 'PNSA3', 'Mor26', 'Mor11m', 'Mor12se',
 'PPSA2', 'Mor04', 'GeomPetitjeanIndex', 'Mor10m', 'Mor22m', 'Mor09p', 'Mor19v', 'PNSA2', 'Mor14m',
 'TASA', 'Mor27se', 'Mor06v', 'Mor01v', 'Mor01', 'Mor04v', 'Mor28p', 'Mor20se',
 'PNSA1', 'Mor22se', 'Mor13', 'Mor32se', 'Mor20m', 'Mor23', 'Mor29se', 'FPSA5',
 'Mor07m', 'Mor15p', 'Mor30', 'WPSA2', 'FNSA2', 'DPSA4', 'GeomRadius', 'Mor24se', 'Mor04m', 'FPSA4',
 'Mor05v', 'Mor17p', 'Mor05p', 'Mor05', 'Mor12p', 'Mor10v', 'Mor09se', 'Mor30p',
 'Mor29m', 'Mor23p', 'MOMI-Z', 'Mor05se', 'Mor07se', 'Mor32v', 'Mor29p', 'Mor31se',
 'Mor09', 'Mor11se', 'GRAVH', 'FPSA3', 'Mor01se', 'Mor08se', 'Mor07', 'Mor08m',
 'Mor24m', 'PPSA1', 'Mor18v', 'Mor10p', 'Mor31p', 'Mor32m', 'WNSA5', 'Mor06p', 'Mor16', 'Mor01m',
 'RASA', 'Mor27', 'Mor25v', 'Mor09m', 'Mor02se', 'Mor20v', 'Mor27v', 'FNSA1',
 'Mor32', 'PPSA5', 'DPSA1', 'Mor28m', 'WNSA1', 'WPSA5', 'Mor12v', 'Mor26m',
 'WPSA1', 'Mor13se', 'GeomDiameter', 'Mor20', 'Mor06se', 'Mor13p', 'Mor14', 'Mor03se', 'DPSA5',
 'Mor11p', 'FPSA2', 'GRAVp', 'Mor22v', 'GRAVHp', 'Mor18m', 'Mor07v', 'Mor18',
 'Mor05m', 'Mor08v', 'Mor30se', 'RNCS', 'PNSA5', 'Mor12', 'MOMI-Y', 'Mor22', 'Mor13m', 'Mor24', 'Mor03v',
 'MOMI-X', 'WNSA2', 'WPSA3', 'Mor16p'], axis=1)

# %%
df_mordred['InChIKey']=df['InChIKey']
df_mordred.head()
# Out:
#     Mor18se   Mor28se     FNSA4    Mor25m    Mor17m     Mor02v    Mor04p  \
# 0 -1.973225 -0.404979 -0.021505  0.120535 -0.585555  37.757073  0.128559
# 1 -1.888216 -0.088030 -0.029747  0.830391 -0.213091  26.668812  0.816339
# 2 -1.997147 -0.274159 -0.022813  0.475747 -0.284050  32.390888  0.313195
# 3 -2.614327 -0.579685 -0.014229  0.116571 -0.299544  40.824868  0.614910
# 4 -1.914067  0.053025 -0.024397  0.479588 -0.505986  40.056068  1.093724
#
#          DPSA2   Mor16se   Mor26se  ...        MOMI-Y     Mor22    Mor13m  \
# 0  3897.199479  1.008949  0.946437  ...  15768.154356 -0.295204 -1.588116
# 1  1578.589335  0.449103  0.562716  ...   8726.965286  0.052017 -1.026099
# 2  2544.935523 -0.152486  0.017027  ...  22003.676476 -0.390081 -1.622054
# 3  3783.815228 -1.533877  0.767914  ...  13408.809965 -1.491542 -2.673645
# 4  3177.893415  1.186759  0.465564  ...  20626.200545 -0.936104 -1.988961
#
#       Mor24    Mor03v        MOMI-X        WNSA2      WPSA3    Mor16p  \
# 0 -0.432878 -7.809859  25059.150870 -1811.589892  32.007542  0.134594
# 1 -0.243506 -2.732247   9811.121749  -478.581452  19.023716  0.435744
# 2 -0.195189 -5.518716  22500.169020  -876.198547  21.906323 -0.347644
# 3 -0.147513 -6.888280  21409.236226  -990.250053  30.077790 -1.313306
# 4 -0.425866 -6.856492  22378.679970 -1527.887228  17.372687 -0.138620
#
#                       InChIKey
# 0  AAMCCXZHVCUGJS-UHFFFAOYSA-N
# 1  AANWVQVQZDEWDD-UHFFFAOYSA-N
# 2  AAZMPANXGYITPF-UHFFFAOYSA-N
# 3  ABHVKYFWPPHTHF-UHFFFAOYSA-N
# 4  ABOSMIZKCHEJEN-UHFFFAOYSA-N
#
# [5 rows x 214 columns]

# %%
#export DataFrame to CSV file
#df_mordred.to_csv(r'C:\documenten hier\ccr2_3D_descriptor_nieuw.csv', index=False)
#df_2.to_csv(r'C:\documenten hier\ccr2_Mordred_full.csv', index=False)

# %% [markdown]
# ### 3D descriptor calculation CCR5

# %%
df_ccr5 = pd.read_csv (r'C:\documenten hier\ccr5_data.csv')
df_ccr5["mol"] = df_ccr5.apply(lambda row: Chem.MolFromSmiles(row['SMILES']), axis=1)
df_ccr5["mol_H"] = df_ccr5.apply(lambda row: Chem.AddHs(row['mol']), axis=1)
df_ccr5.head()

# %%
mols5 = df['mol_H'].values.tolist()
print(mols5)

# %%
# run ETKDG 5 times
cids = df_ccr5.apply(lambda row: AllChem.EmbedMultipleConfs(row['mol_H'],numConfs=5), axis=1)
#print(len(cids))

rmslist = []
df_ccr5.apply(lambda row: AllChem.AlignMolConformers(row['mol_H'],RMSlist=rmslist), axis=1)
print(len(rmslist))

# %%
from mordred import Calculator, descriptors
calc = Calculator(descriptors)
print(calc.pandas(mols5))

# %%
df_2_ccr5 = pd.DataFrame(data = calc.pandas(mols5))
df_2_ccr5

# %%
# new dataframe that contains all the 3D descriptor data
df_mordred_ccr5= df_2_ccr5.filter(['Mor18se', 'Mor28se', 'FNSA4', 'Mor25m', 'Mor17m', 'Mor02v', 'Mor04p', 'DPSA2',
 'Mor16se', 'Mor26se', 'Mor15v', 'Mor28v', 'Mor14v', 'Mor25se',
 'Mor30m', 'Mor03p', 'PPSA4', 'Mor27m', 'Mor10se', 'PBF', 'Mor21se', 'GRAV',
 'Mor25p', 'Mor23m', 'Mor20p', 'Mor18p', 'Mor21m', 'Mor23se', 'Mor15m', 'FNSA3',
 'Mor08p', 'Mor31m', 'WNSA4', 'Mor22p', 'Mor27p', 'FPSA1', 'Mor19p', 'Mor16m',
 'Mor01p', 'WNSA3', 'Mor06', 'Mor29', 'Mor16v', 'Mor26p', 'Mor03m', 'Mor11', 'Mor25', 'Mor19m',
 'Mor17v', 'Mor14se', 'Mor31v', 'Mor19se', 'DPSA3', 'PPSA3', 'Mor09v', 'Mor06m', 'Mor17',
 'Mor11v', 'Mor15', 'Mor21v', 'Mor14p', 'WPSA4', 'Mor28', 'Mor32p',
 'Mor02p', 'FNSA5', 'Mor29v', 'Mor21', 'Mor17se', 'RPSA', 'Mor24v', 'Mor26v',
 'Mor30v', 'RPCS', 'Mor03', 'Mor02m', 'Mor19', 'PNSA4', 'Mor13v', 'Mor07p',
 'Mor08', 'Mor15se', 'Mor21p', 'GeomShapeIndex', 'TPSA', 'Mor23v', 'Mor04se', 'Mor31',
 'Mor02', 'Mor24p', 'Mor12m', 'Mor10', 'PNSA3', 'Mor26', 'Mor11m', 'Mor12se',
 'PPSA2', 'Mor04', 'GeomPetitjeanIndex', 'Mor10m', 'Mor22m', 'Mor09p', 'Mor19v', 'PNSA2', 'Mor14m',
 'TASA', 'Mor27se', 'Mor06v', 'Mor01v', 'Mor01', 'Mor04v', 'Mor28p', 'Mor20se',
 'PNSA1', 'Mor22se', 'Mor13', 'Mor32se', 'Mor20m', 'Mor23', 'Mor29se', 'FPSA5',
 'Mor07m', 'Mor15p', 'Mor30', 'WPSA2', 'FNSA2', 'DPSA4', 'GeomRadius', 'Mor24se', 'Mor04m', 'FPSA4',
 'Mor05v', 'Mor17p', 'Mor05p', 'Mor05', 'Mor12p', 'Mor10v', 'Mor09se', 'Mor30p',
 'Mor29m', 'Mor23p', 'MOMI-Z', 'Mor05se', 'Mor07se', 'Mor32v', 'Mor29p', 'Mor31se',
 'Mor09', 'Mor11se', 'GRAVH', 'FPSA3', 'Mor01se', 'Mor08se', 'Mor07', 'Mor08m',
 'Mor24m', 'PPSA1', 'Mor18v', 'Mor10p', 'Mor31p', 'Mor32m', 'WNSA5', 'Mor06p', 'Mor16', 'Mor01m',
 'RASA', 'Mor27', 'Mor25v', 'Mor09m', 'Mor02se', 'Mor20v', 'Mor27v', 'FNSA1',
 'Mor32', 'PPSA5', 'DPSA1', 'Mor28m', 'WNSA1', 'WPSA5', 'Mor12v', 'Mor26m',
 'WPSA1', 'Mor13se', 'GeomDiameter', 'Mor20', 'Mor06se', 'Mor13p', 'Mor14', 'Mor03se', 'DPSA5',
 'Mor11p', 'FPSA2', 'GRAVp', 'Mor22v', 'GRAVHp', 'Mor18m', 'Mor07v', 'Mor18',
 'Mor05m', 'Mor08v', 'Mor30se', 'RNCS', 'PNSA5', 'Mor12', 'MOMI-Y', 'Mor22', 'Mor13m', 'Mor24', 'Mor03v',
 'MOMI-X', 'WNSA2', 'WPSA3', 'Mor16p'], axis=1)

# %%
df_mordred_ccr5['InChIKey']=df_ccr5['InChIKey']
df_mordred_ccr5.head()

# %%
#export DataFrame to CSV file
#df_mordred_ccr5.to_csv(r'C:\documenten hier\ccr5_3D_descriptor_nieuw.csv', index=False)
#df_2_ccr5.to_csv(r'C:\documenten hier\ccr5_Mordred_full.csv', index=False)
